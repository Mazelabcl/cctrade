# %%
import pandas as pd
import numpy as np

# %%
datafile = "ml_features_dataset.csv"

# %%
df = pd.read_csv(datafile)

# %%
# df.head()

# %%
df['is_fractal'] = df['is_fractal_up'] | df['is_fractal_down']

# %%
df['is_fractal_target2'] = np.where(df['is_fractal_up'] == 1, -1, 
                                     np.where(df['is_fractal_down'] == 1, 1, 0))

# down = 1
# up = -1

# %%
# df[['is_fractal_target2', 'is_fractal', 'is_fractal_down', 'is_fractal_up']].head(50)

# %%
df.to_csv('ml_features_dataset_target.csv', index=False)
